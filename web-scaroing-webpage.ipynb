# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.tutorialsfreak.com/")

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify)

# %% [markdown]
# # Finds the first <div> with class 'app-container' and retrieves all <h1> tags inside it.

# %%
class_data=soup.find("div",class_="app-container")
class_data.find_all("h1") #-----class_ not found

# %% [markdown]
# # Finds and returns the first <div> tag from the webpage’s HTML structure.

# %%
class_data=soup.find("div")
class_data

# %%
class_data=soup.find("div",class_="wrapperr")
class_data

# %%
id_data=soup.find("div",id="app-fronted")
id_data
