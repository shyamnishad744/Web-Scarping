# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.tutorialsfreak.com/")

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify)

# %%
lines=soup.find_all("p")
lines

# %%
for l in lines:
    print(l.text)

# %%
s=soup.find("div",class_="section-subheading")

# %%
line_1=s.find_all("p")
line_1
