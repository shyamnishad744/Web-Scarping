# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.tutorialsfreak.com/")
print(web)

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")
soup

# %%
print(soup.prettify())

# %%
soup.title

# %%
soup.title.name

# %%
soup.p  #extrcted first parahgraph tag

# %%
soup.a #extracted first anchor  [  a  ] tag

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# # Accesses the <html> tag of the page and checks its object type in BeautifulSoup

# %%
tag=soup.html
type(tag)

# %%
tag=soup.p
tag

# %%
tag=soup.a
tag

# %%
tag=soup.h1
tag

# %% [markdown]
# #NAVIGABLESTRING --- TO EXTRACTING  STRING FROM TAGS

# %% [markdown]
# # Extracts and displays the text content (string) from the first <p> tag in the HTML.

# %%
tag=soup.p.string
tag

# %%
tag=soup.h1.string
tag

# %% [markdown]
# BEAUTIFULSOUP---

# %%
soup.find("h1")

# %%
soup.find_all("h1")

# %%
soup.find("h1")

# %%
soup.find_all("p")

# %% [markdown]
# COMMENT

# %% [markdown]
# # Extracts the text inside the first <h1> tag and stores it in 'com'

# %%
com=soup.h1.string
com

# %% [markdown]
# #WEB
